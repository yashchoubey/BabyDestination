# %%
import pandas as pd
df = pd.read_excel('Data Analyst Test.xlsx', sheet_name=1,header=1,shuffle=False)
df['Date'] =pd.to_datetime(df.Date)
df=df.drop(df.index[338:])
label=df['Likes']

df.drop(['Date'], axis=1, inplace=True)
df = (df - df.mean()) / (df.max() - df.min())

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Engaged users'], df['reach'], df['impressions'])

ax.set_xlabel('Engaged users Label')
ax.set_ylabel('reach Label')
ax.set_zlabel('impressions Label')
plt.show()

# %%
plt.plot(df['Engaged users'], df['reach'],marker='o',linestyle = 'None',)
plt.xlabel('Engaged users')
plt.ylabel('Reach')
plt.show()
plt.plot(df['impressions'], df['reach'],marker='o',linestyle = 'None',)
plt.xlabel('Impressions')
plt.ylabel('Reach')
plt.show()
plt.plot(df['impressions'], df['Engaged users'],marker='o',linestyle = 'None',)
plt.ylabel('Engaged users')
plt.xlabel('Impressions')
plt.show()

# %%
df.drop(['Likes'], axis=1, inplace=True)
df.head()
# Out:
#    Engaged users     reach  impressions
# 0      -0.100799 -0.036992    -0.052852
# 1      -0.076653 -0.031274    -0.038736
# 2      -0.078718 -0.031081    -0.045294
# 3      -0.070934 -0.029352    -0.039968
# 4      -0.069663 -0.028886    -0.040897

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,label, test_size=0.115, shuffle=False)

# %%
# print len(X_train)
# print len(X_test)
# print len(y_train)
# print label

# %%
from sklearn.linear_model import Ridge
from sklearn import model_selection

model = Ridge()
results = model_selection.cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error')
print("MAE: %.3f (%.3f)") % (results.mean(), results.std())

print results
# Out:
# MAE: -45.576 (1.427)
# [-46.02202018 -43.64853976 -47.05774026]

# %%
df.drop(['Engaged users'], axis=1, inplace=True)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,label, test_size=0.115, shuffle=False)

# %%
from sklearn.linear_model import Ridge
from sklearn import model_selection

model = Ridge()
results = model_selection.cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error')
print("MAE: %.3f (%.3f)") % (results.mean(), results.std())

print results
# Out:
# MAE: -48.053 (1.261)
# [-49.39680506 -46.36582516 -48.39627284]
