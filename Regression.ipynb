# %%
import pandas as pd
df = pd.read_excel('Data Analyst Test.xlsx')
df.head()
# Out:
#                            Post ID content type Date posted  click  reach  \
# 0  917697664961970_921719407893129        Photo  2015-08-11     11     17
# 1  917697664961970_922187454512991        Photo  2015-08-11     23     54
# 2  917697664961970_922176597847410        Photo  2015-08-11      9     16
# 3  917697664961970_921722437892826        Photo  2015-08-11      0      0
# 4  917697664961970_922199271178476         Link  2015-09-11    657    896
#
#    impression
# 0           1
# 1           5
# 2           9
# 3           0
# 4         654

# %%
label=df['click']
df.drop(['Post ID','content type','Date posted','click'], axis=1, inplace=True)
df.head()
# Out:
#    reach  impression
# 0     17           1
# 1     54           5
# 2     16           9
# 3      0           0
# 4    896         654

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df,label, test_size=0.11, shuffle=False)

# %%
len(X_train)
# Out:
# 299

# %%
from sklearn.linear_model import SGDClassifier
model = SGDClassifier(loss='perceptron',verbose=1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

print model.score(X_test, y_test)
# Out:
# -- Epoch 1
# Norm: 20429.38, NNZs: 2, Bias: 9.880735, T: 299, Avg. loss: 0.033611
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 16604.47, NNZs: 2, Bias: 9.880735, T: 598, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 13985.94, NNZs: 2, Bias: 9.880735, T: 897, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 12080.79, NNZs: 2, Bias: 9.880735, T: 1196, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 10632.45, NNZs: 2, Bias: 9.880735, T: 1495, Avg. loss: 0.000000
# Total training time: 0.00 seconds.
# -- Epoch 1
# Norm: 42278.46, NNZs: 2, Bias: -1.645781, T: 299, Avg. loss: 153.107795
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 34356.58, NNZs: 2, Bias: -1.554337, T: 598, Avg. loss: 135.211890
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 28933.28, NNZs: 2, Bias: -1.481050, T: 897, Avg. loss: 111.543850
# Total training time: 0.00 seconds.
# -- Epoch 4
# ...
